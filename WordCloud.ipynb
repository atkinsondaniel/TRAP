# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
with open('data/nostopwords.txt', 'r') as content_file:
    emails = content_file.read()

# %%
words = emails.split(" ")

# %%
good = [word for word in good if word != "end"]

# %%
better = ' '.join(good)

# %%
wordcloud = WordCloud(background_color="white", max_words=50, max_font_size = 500).generate(better)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.savefig('data/img.png')
